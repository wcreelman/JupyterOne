# %% [markdown]
# Yes this is my life
# ==============

# %%
print ("Hello World")
# Out:
# Hello World

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import scipy as sp
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colours = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2
plt.xlabel('x scale')
plt.ylabel('y scale')
plt.title("thisis my Title")

plt.scatter(x, y, s=area, c=colours, alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
